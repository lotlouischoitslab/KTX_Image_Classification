# %% [markdown]
# # 1. Organizing Images

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import load_img

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import random
from random import choice 

import os
os.chdir('C:/Users/LOTLOUISCHO/Desktop/02MyProjects/ktx_project')
import glob
from skimage.io import imread

import warnings
warnings.filterwarnings("ignore")

# %%
#0 means KTX-1
#1 means KTX-EUM
#2 means KTX-Sancheon
#3 means SRT
hsr0 = []
hsr1 = []
hsr2 = []
hsr3 = []

# %%
for classes in os.listdir('trains'):
    route = 'trains/'+classes+'/'
    for path in os.listdir(route):
        if classes == 'ktx_1':
            hsr0.append(route+path)
        elif classes == 'ktx_eum':
            hsr1.append(route+path)
        elif classes == 'ktx_sancheon':
            hsr2.append(route+path)
        elif classes == 'srt':
            hsr3.append(route+path)

# %%
print('KTX-1:',len(hsr0))
print('KTX-EUM:',len(hsr2))
print('KTX-Sancheon:',len(hsr1))
print('SRT:',len(hsr3))
# Out:
# KTX-1: 10
# KTX-EUM: 10
# KTX-Sancheon: 10
# SRT: 10

# %% [markdown]
# # 2. Exploratory Data Analysis

# %%
from random import choice #for randomly selecting images from arrays above
fig,axes = plt.subplots(figsize=(20,25))
  
random_image = [choice(hsr0)for x in range(0,11)] #setting the length of array at 10 to print 10 images
for i in range(0,len(random_image)):
    img = imread(random_image[i])
    plt.imshow(img)
    axes =plt.subplot(5,5,i+1)
    axes.set_title('KTX:'+str(random_image[i][11:12]),fontsize=20) #sets the title as 1 to indicate malignant

fig.delaxes(axes)
fig.suptitle('Random KTX Samples',fontsize=30)
plt.show()

# %%
fig,axes = plt.subplots(figsize=(20,25))
  
random_image = [choice(hsr1)for x in range(0,11)] #setting the length of array at 10 to print 10 images
for i in range(0,len(random_image)):
    img = imread(random_image[i])
    plt.imshow(img)
    axes =plt.subplot(5,5,i+1)
    axes.set_title('KTX:'+str(random_image[i][11:14]),fontsize=20) #sets the title as 1 to indicate malignant

fig.delaxes(axes)
fig.suptitle('Random KTX Samples',fontsize=30)
plt.show()

# %%
fig,axes = plt.subplots(figsize=(20,25))
  
random_image = [choice(hsr2)for x in range(0,11)] #setting the length of array at 10 to print 10 images
for i in range(0,len(random_image)):
    img = imread(random_image[i])
    plt.imshow(img)
    axes =plt.subplot(5,5,i+1)
    axes.set_title('KTX:'+str(random_image[i][11:19]),fontsize=20) #sets the title as 1 to indicate malignant

fig.delaxes(axes)
fig.suptitle('Random KTX Samples',fontsize=30)
plt.show()

# %%
fig,axes = plt.subplots(figsize=(20,25))
  
random_image = [choice(hsr3)for x in range(0,11)] #setting the length of array at 10 to print 10 images

for i in range(0,len(random_image)):
    img = imread(random_image[i])
    plt.imshow(img)
    axes =plt.subplot(5,5,i+1)
    axes.set_title('SRT:'+str(random_image[i][15:16]),fontsize=20) #sets the title as 1 to indicate malignant

fig.delaxes(axes)
fig.suptitle('Random KTX Samples',fontsize=30)
plt.show()

# %% [markdown]
# # 3. Create Training and Testing Image Datasets

# %%
batch_size = 32 #batch size is a number of samples processed before the model is updated
img_height = 180 #height of our image
img_width = 180 #width of our image
epochs = 10 #number of steps

# %%
training_data = tf.keras.preprocessing.image_dataset_from_directory(
    'trains',
    validation_split=0.2, #training and testing images are split around 80-20%
    subset="training", #we are going to 'train' these datasets
    seed=123, #random seed number
    image_size=(img_height, img_width), #adjust the image size
    batch_size=batch_size) #given batch size
# Out:
# Found 40 files belonging to 4 classes.
# Using 32 files for training.

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
  'trains',
    validation_split=0.2,
    subset="validation", #we are going to 'test' these datasets
    seed=123, #random seed number
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 40 files belonging to 4 classes.
# Using 8 files for validation.

# %%
AUTOTUNE = tf.data.AUTOTUNE
training_data = training_data.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_data = val_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# # 4. CNN Model Creation

# %%
num_classes = 4
epochs=20
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dense(num_classes, activation='softmax'),
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model_history = model.fit(
  training_data,
  validation_data=val_data,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 1.3862 - accuracy: 0.4375 - val_loss: 1.4371 - val_accuracy: 0.1250
# Epoch 2/20
# 1/1 [==============================] - 0s 499ms/step - loss: 1.3504 - accuracy: 0.2812 - val_loss: 1.2803 - val_accuracy: 0.8750
# Epoch 3/20
# 1/1 [==============================] - 0s 474ms/step - loss: 1.2685 - accuracy: 0.9688 - val_loss: 1.2340 - val_accuracy: 0.3750
# Epoch 4/20
# 1/1 [==============================] - 0s 481ms/step - loss: 1.1192 - accuracy: 0.5000 - val_loss: 1.1494 - val_accuracy: 0.3750
# Epoch 5/20
# 1/1 [==============================] - 0s 475ms/step - loss: 1.2792 - accuracy: 0.3125 - val_loss: 1.2517 - val_accuracy: 0.6250
# Epoch 6/20
# 1/1 [==============================] - 0s 478ms/step - loss: 0.9008 - accuracy: 0.7812 - val_loss: 1.1914 - val_accuracy: 0.6250
# Epoch 7/20
# 1/1 [==============================] - 0s 485ms/step - loss: 0.9033 - accuracy: 0.5938 - val_loss: 0.7183 - val_accuracy: 0.7500
# Epoch 8/20
# 1/1 [==============================] - 0s 480ms/step - loss: 0.6044 - accuracy: 0.9062 - val_loss: 0.6042 - val_accuracy: 1.0000
# Epoch 9/20
# 1/1 [==============================] - 0s 479ms/step - loss: 0.6112 - accuracy: 0.8750 - val_loss: 0.4634 - val_accuracy: 1.0000
# Epoch 10/20
# 1/1 [==============================] - 0s 477ms/step - loss: 0.4445 - accuracy: 0.8750 - val_loss: 0.3471 - val_accuracy: 0.8750
# Epoch 11/20
# 1/1 [==============================] - 0s 483ms/step - loss: 0.2597 - accuracy: 0.9688 - val_loss: 0.3890 - val_accuracy: 0.7500
# Epoch 12/20
# 1/1 [==============================] - 0s 484ms/step - loss: 0.1996 - accuracy: 0.9375 - val_loss: 0.3131 - val_accuracy: 0.8750
# Epoch 13/20
# 1/1 [==============================] - 0s 488ms/step - loss: 0.1511 - accuracy: 0.9375 - val_loss: 0.0877 - val_accuracy: 1.0000
# Epoch 14/20
# 1/1 [==============================] - 0s 483ms/step - loss: 0.0709 - accuracy: 1.0000 - val_loss: 0.0877 - val_accuracy: 1.0000
# Epoch 15/20
# 1/1 [==============================] - 0s 484ms/step - loss: 0.0563 - accuracy: 1.0000 - val_loss: 0.1085 - val_accuracy: 0.8750
# Epoch 16/20
# 1/1 [==============================] - 0s 479ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.3688 - val_accuracy: 0.8750
# Epoch 17/20
# 1/1 [==============================] - 0s 477ms/step - loss: 0.0251 - accuracy: 0.9688 - val_loss: 0.2773 - val_accuracy: 0.8750
# Epoch 18/20
# 1/1 [==============================] - 0s 487ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 19/20
# 1/1 [==============================] - 0s 467ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 20/20
# 1/1 [==============================] - 0s 475ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000

# %%
training_acc = model_history.history['accuracy'] #training accuracy
testing_acc = model_history.history['val_accuracy'] #test accuracy

training_loss = model_history.history['loss'] #training loss
testing_loss = model_history.history['val_loss'] #test loss

# %%
plt.plot(range(epochs),training_acc,'b',label='Training Accuracy')
plt.plot(range(epochs), testing_acc, 'r', label='Testing Accuracy')
plt.title('Accuracy Graph')
plt.xlabel('Epochs')
plt.ylabel('Accuracy Score')
plt.legend()
plt.figure()

# %%
plt.plot(range(epochs),training_loss,'b',label='Training Loss')
plt.plot(range(epochs), testing_loss, 'r', label='Testing Loss')
plt.title('Loss Graph')
plt.xlabel('Epochs')
plt.ylabel('Loss Score')
plt.legend()
plt.figure()

# %% [markdown]
# # Predicting with Given Images

# %%
class_names = ['KTX-1','KTX-EUM','KTX-Sancheon','SRT']

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)
    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in val_data.take(1):
    for i in range(8):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
