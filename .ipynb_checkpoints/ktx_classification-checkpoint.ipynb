# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import random
os.chdir('C:/Users/LOTLOUISCHO/Desktop/02MyProjects/ktx_project')
from tensorflow.keras.preprocessing.image import load_img

# %%
#0 means KTX-1
#1 means KTX-Sancheon
#2 means KTX-EUM
#3 means SRT
input_path = []
label = []

for classes in os.listdir('trains'):
    for path in os.listdir('trains/'+classes):
        if classes == 'ktx_1':
            label.append(0)
        elif classes == 'ktx_sancheon':
            label.append(1)
        elif classes == 'ktx_eum':
            label.append(2)
        elif classes == 'srt':
            label.append(3)
        input_path.append(os.path.join('trains',classes,path))

# %%
df = pd.DataFrame()
df['images'] = input_path
df['label'] = label
df = df.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# https://www.youtube.com/watch?v=ENXr1foShrA

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#display grid of images
train_types = ['KTX-1','KTX-Sancheon','KTX-EUM','SRT']
for i in range(4):
    plt.figure(figsize=(25,35))
    temp = df[df['label']==i]['images']
    start = random.randint(0,len(temp))
    files = temp[start:start+25]

    for index,file in enumerate(files):
        plt.subplot(5,5,index+1)
        img = load_img(file)
        img = np.array(img)
        plt.imshow(img)
        plt.title(train_types[i])
        plt.axis('off')

# %%
import seaborn as sns
sns.countplot(df['label'])
# Out:
# C:\Users\LOTLOUISCHO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# ## Create Data Generator for the Images

# %%
df['label'] = df['label'].astype('str')
df.head()
# Out:
#                               images label
# 0         trains\ktx_1\ktx_one_4.png     0
# 1       trains\ktx_eum\ktx_eum_1.png     2
# 2               trains\srt\srt_8.png     3
# 3  trains\ktx_sancheon\ktx_san_4.png     1
# 4       trains\ktx_eum\ktx_eum_0.png     2

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df,test_size=0.2,random_state=42)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_generator = ImageDataGenerator(
    rescale=1./255, #normalization
    rotation_range=40, #augmentation of images to prevent overfitting
    shear_range = 0.2, 
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest'
)

val_generator = ImageDataGenerator(rescale=1./255)

train_iterator = train_generator.flow_from_dataframe(
    train,
    x_col='images',
    y_col='label',
    target_size=(128,128),
    batch_size=512,
    class_mode='categorical')

val_iterator = val_generator.flow_from_dataframe(
    test,
    x_col='images',
    y_col='label',
    target_size=(128,128),
    batch_size=512,
    class_mode='categorical')
# Out:
# Found 32 validated image filenames belonging to 4 classes.
# Found 8 validated image filenames belonging to 4 classes.

# %% [markdown]
# ## Model Creation

# %%
from keras import Sequential
from keras.layers import Conv2D,MaxPool2D,Flatten,Dense

# %%
model = Sequential([
    Conv2D(16,(3,3),activation='relu',input_shape=(128,128,3)),
    MaxPool2D((2,2)),
    Conv2D(32,(3,3),activation='relu'),
    MaxPool2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    MaxPool2D((2,2)),
    Flatten(), #convert to single dimension
    Dense(512,activation='relu'),
    Dense(1,activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,447,137
# Trainable params: 6,447,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
output = model.fit(train_iterator,epochs=10,validation_data=val_iterator)
# Out:
# C:\Users\LOTLOUISCHO\anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:822: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 1/10
# 1/1 [==============================] - 2s 2s/step - loss: 0.7277 - accuracy: 0.2500 - val_loss: 3.2366 - val_accuracy: 0.7500
# Epoch 2/10
# 1/1 [==============================] - 1s 776ms/step - loss: 2.9833 - accuracy: 0.7500 - val_loss: 1.7713 - val_accuracy: 0.7500
# Epoch 3/10
# 1/1 [==============================] - 1s 680ms/step - loss: 1.6420 - accuracy: 0.7500 - val_loss: 0.7532 - val_accuracy: 0.7500
# Epoch 4/10
# 1/1 [==============================] - 1s 639ms/step - loss: 0.7167 - accuracy: 0.7500 - val_loss: 0.5874 - val_accuracy: 0.7500
# Epoch 5/10
# 1/1 [==============================] - 1s 699ms/step - loss: 0.5897 - accuracy: 0.7500 - val_loss: 0.6968 - val_accuracy: 0.4375
# Epoch 6/10
# 1/1 [==============================] - 1s 759ms/step - loss: 0.6898 - accuracy: 0.6406 - val_loss: 0.7056 - val_accuracy: 0.2500
# Epoch 7/10
# 1/1 [==============================] - 1s 744ms/step - loss: 0.6994 - accuracy: 0.2656 - val_loss: 0.6752 - val_accuracy: 0.7500
# Epoch 8/10
# 1/1 [==============================] - 1s 722ms/step - loss: 0.6739 - accuracy: 0.7500 - val_loss: 0.6429 - val_accuracy: 0.7500
# Epoch 9/10
# 1/1 [==============================] - 1s 716ms/step - loss: 0.6437 - accuracy: 0.7500 - val_loss: 0.6171 - val_accuracy: 0.7500
# Epoch 10/10
# 1/1 [==============================] - 1s 752ms/step - loss: 0.6211 - accuracy: 0.7500 - val_loss: 0.5959 - val_accuracy: 0.7500

# %%
accuracy = output.history['accuracy']
valid_accuracy = output.history['val_accuracy']
epochs = range(len(accuracy))

# %%
plt.plot(epochs,accuracy,'b',label='Training Accuracy')
plt.plot(epochs, valid_accuracy, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.xlabel('Number of trials')
plt.ylabel('Probability')
plt.legend()
plt.figure()

# %%
loss = output.history['loss']
val_loss = output.history['val_loss']
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.xlabel('Number of trials')
plt.ylabel('Probability')
plt.legend()
plt.show()
