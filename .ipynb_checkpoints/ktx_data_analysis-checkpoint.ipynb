# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from datetime import datetime

# %%
#Units: Passengers per thousand
#Resources: 한국철도공사 및 (주)SR에서 제공하는「KTX, SRT 여객 수송 통계」

# %%
data = pd.read_excel('data.xls')

# %%
data
# Out:
#      Unnamed: 0 200404월 200405월 200406월 200407월 200408월 200409월 200410월  \
# 0    고속철도 여객수 계   2,127   2,314   1,968   2,152   2,247   2,255   2,278
# 1        KTX이용률      61      65      57      61      65      65      65
# 2        SRT이용률       -       -       -       -       -       -       -
# 3    경부선 KTX여객수   1,771   1,945   1,695   1,845   1,893   1,825   1,912
# 4    경부선 KTX이용률      70      75      67      72      75      73      76
# 5    경부선 SRT여객수       -       -       -       -       -       -       -
# 6    경부선 SRT이용률       -       -       -       -       -       -       -
# 7    호남선 KTX여객수     356     369     273     307     354     430     366
# 8    호남선 KTX이용률      38      39      30      32      37      45      38
# 9    호남선 SRT여객수       -       -       -       -       -       -       -
# 10   호남선 SRT이용률       -       -       -       -       -       -       -
# 11   경전선 KTX여객수       -       -       -       -       -       -       -
# 12  경전선  KTX이용률       -       -       -       -       -       -       -
# 13   전라선 KTX여객수       -       -       -       -       -       -       -
# 14   전라선 KTX이용률       -       -       -       -       -       -       -
# 15   동해선 KTX여객수       -       -       -       -       -       -       -
# 16   동해선 KTX이용률       -       -       -       -       -       -       -
#
#    200411월 200412월  ... 202105월 202106월 202107월 202108월 202109월 202110월  \
# 0    2,200   2,340  ...   5,910   5,729   5,071   5,024   5,130   6,427
# 1       66      65  ...      70      71      59      57      60      74
# 2        -       -  ...     106     108      96      96      94     114
# 3    1,838   1,974  ...   2,102   2,060   1,770   1,695   1,799   2,292
# 4       76      75  ...      66      68      56      53      58      71
# 5        -       -  ...   1,292   1,249   1,158   1,132   1,107   1,365
# 6        -       -  ...     112     116     102     102     100     121
# 7      363     366  ...     701     673     578     586     611     756
# 8       39      37  ...      66      62      52      51      55      66
# 9        -       -  ...     508     495     446     452     438     537
# 10       -       -  ...      94      94      82      84      84     100
# 11       -       -  ...     437     422     366     379     405     507
# 12       -       -  ...      81      82      68      65      71      86
# 13       -       -  ...     495     473     424     447     435     554
# 14       -       -  ...      82      81      70      68      67      84
# 15       -       -  ...     375     357     329     333     335     416
# 16       -       -  ...      85      84      73      68      70      85
#
#    202111월 202112월 202201월 202202월
# 0    6,866   6,375   5,798   4,959
# 1       85      74      67      62
# 2      120     113     102      99
# 3    2,521   2,280   2,079   1,754
# 4       82      72      65      60
# 5    1,382   1,356   1,258   1,111
# 6      128     120     108     105
# 7      821     743     662     553
# 8       74      65      59      53
# 9      553     534     483     419
# 10     106      98      89      86
# 11     546     501     460     381
# 12      97      86      79      71
# 13     586     543     486     423
# 14      93      83      76      70
# 15     457     418     370     318
# 16      96      85      79      72
#
# [17 rows x 216 columns]

# %%
init = True
my_list = []
for c in data:
    if init == True:
        init = False
    else:
        temp_list = data[c].values
        for i in range(len(temp_list)):
            if temp_list[i] == '-':
                temp_list[i] = 0
        my_list.append(temp_list)

# %%
my_list = np.array(my_list)
rows = len(my_list)
cols = len(my_list[0])

# %%
for i in range(rows):
    for j in range(cols):
        my_list[i][j] = str(my_list[i][j])

# %%
for i in range(rows):
    for j in range(cols):
        remove_comma = my_list[i][j].replace(',','')
        f = float(remove_comma)
        my_list[i][j] = f

# %%
df = {}
year = 2004
x = []
for m in range(4,13):
    if m < 10:
        x.append(str(0)+str(m)+'-01-'+str(year))
    else:
        x.append(str(m)+'-01-'+str(year))
year +=1
for y in range(18):
    for m in range(1,13):
        if m < 10:
            x.append(str(0)+str(m)+'-01-'+str(year))
        else:
            x.append(str(m)+'-01-'+str(year))
    year +=1

# %%
x = x[:-10]
len(x)
# Out:
# 215

# %%
df['Time'] = x
df['Time'] = pd.to_datetime(df['Time'])
time_series = pd.DataFrame(df)
time_series = time_series.set_index('Time')

# %% [markdown]
# ### High Speed Train Lines

# %%
ktx = 'KTX'
srt = 'SRT'
gyeongbu = 'Gyeongbu'
honam = 'Honam'
gyeongjeon = 'Gyeongjeon'
jeolla = 'Jeolla'
donghae = 'Donghae'

lines = [gyeongbu,honam,gyeongjeon,jeolla,donghae]
passengers = 'Passengers'
utility = 'Utility Rate'

# %%
total_list = ['Total Passengers']
utility_list = ['KTX Utility Rate','SRT Utility Rate']
for line in lines:
    if line == gyeongbu or line == honam:
        ktx_add = ktx + ' ' + line + ' ' + passengers
        total_list.append(ktx_add)
        ktx_add = ktx + ' ' + line + ' ' + utility
        utility_list.append(ktx_add)
        srt_add = srt + ' ' + line + ' ' + passengers
        total_list.append(srt_add)
        srt_add = srt + ' ' + line + ' ' + utility
        utility_list.append(srt_add)
    else:
        ktx_add = ktx + ' ' + line + ' ' + passengers
        total_list.append(ktx_add)
        ktx_add = ktx + ' ' + line + ' ' + utility
        utility_list.append(ktx_add)

# %%
total_list
# Out:
# ['Total Passengers',
#  'KTX Gyeongbu Passengers',
#  'SRT Gyeongbu Passengers',
#  'KTX Honam Passengers',
#  'SRT Honam Passengers',
#  'KTX Gyeongjeon Passengers',
#  'KTX Jeolla Passengers',
#  'KTX Donghae Passengers']

# %%
utility_list
# Out:
# ['KTX Utility Rate',
#  'SRT Utility Rate',
#  'KTX Gyeongbu Utility Rate',
#  'SRT Gyeongbu Utility Rate',
#  'KTX Honam Utility Rate',
#  'SRT Honam Utility Rate',
#  'KTX Gyeongjeon Utility Rate',
#  'KTX Jeolla Utility Rate',
#  'KTX Donghae Utility Rate']

# %%
count = 0
for t in total_list:
    time_series[t] = my_list[:,count]
    count +=1

count = 0
for u in utility_list:
    time_series[u] = my_list[:,count]
    count +=1

# %%
time_series
# Out:
#            Total Passengers KTX Gyeongbu Passengers SRT Gyeongbu Passengers  \
# Time
# 2004-04-01           2127.0                    61.0                     0.0
# 2004-05-01           2314.0                    65.0                     0.0
# 2004-06-01           1968.0                    57.0                     0.0
# 2004-07-01           2152.0                    61.0                     0.0
# 2004-08-01           2247.0                    65.0                     0.0
# ...                     ...                     ...                     ...
# 2021-10-01           6427.0                    74.0                   114.0
# 2021-11-01           6866.0                    85.0                   120.0
# 2021-12-01           6375.0                    74.0                   113.0
# 2022-01-01           5798.0                    67.0                   102.0
# 2022-02-01           4959.0                    62.0                    99.0
#
#            KTX Honam Passengers SRT Honam Passengers  \
# Time
# 2004-04-01               1771.0                 70.0
# 2004-05-01               1945.0                 75.0
# 2004-06-01               1695.0                 67.0
# 2004-07-01               1845.0                 72.0
# 2004-08-01               1893.0                 75.0
# ...                         ...                  ...
# 2021-10-01               2292.0                 71.0
